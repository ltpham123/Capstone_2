# %% [markdown]
# # Capstone 2
# For this project, I will be working through reading, cleaning, and analyzing data for a fictional business using sample data. This project will call on my ability to read data and extract useful information using my Python skills.
#
# The Sales Manager assigned to me is Miami Vue.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
given_sales_manager = "Miami Vue"

# %%
product_categories = pd.read_csv("ProductCategories.csv")
print(product_categories.info())
print(product_categories.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     object
#  2   SubcategoryID  52 non-null     object
#  3   Subcategory    52 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.8+ KB
# None
#    CategoryID                  Category SubcategoryID Subcategory
# 0         120  Technology & Accessories       120-tab     Tablets

# %%
products = pd.read_csv("Products.csv")
print(products.info())
print(products.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    object
#  1   Product        669 non-null    object
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 21.0+ KB
# None
#     Prod Num           Product  CategoryID SubcategoryID
# 0  105248-IT  TCL NXTPAPER 10s         120       120-tab

# %%
store_details = pd.read_csv("StoreDetail.csv")
print(store_details.info())
print(store_details.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    object
#  1   State              111 non-null    object
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    object
#  4   Region             111 non-null    object
#  5   Region Director    111 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 5.3+ KB
# None
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers

# %%
store_sales = pd.read_csv("StoreSales.csv")
print(store_sales.info())
print(store_sales.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  object
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  object
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 12.8+ MB
# None
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0         1/1/2022       702        NaN  105349-M          8.0

# %%
customer_list = pd.read_csv("customer_list.csv", sep="|")  # closer inspection, delimiter is long bar '|'
print(customer_list.info())
print(customer_list.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    object
#  2   time          521 non-null    object
#  3   name          521 non-null    object
#  4   email         521 non-null    object
#  5   phone         520 non-null    object
#  6   sms-opt-out   520 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 28.6+ KB
# None
#    cust_id        date      time    name                      email  \
# 0        1  2023-03-15  08:45:12  Rachel  rachel@centralperk.coffee
#
#           phone sms-opt-out
# 0  212-555-1001            N

# %% [markdown]
# ## Core Marketing Analysis

# %% [markdown]
# **Who are the territory managers for the sales territories assigned? What are the store IDs and cities for the stores in each assigned sales territory?**

# %%
# I would like to find what region my assigned territory manager is responsible for
assigned_region = store_details[store_details["Territory Manager"] == given_sales_manager]["Region"].unique()
print(f"Territory Manager: {given_sales_manager} | {assigned_region[0]}\n")  # Only assigned Northeast

assigned_state = store_details[store_details["Territory Manager"] == given_sales_manager]["State"].unique()
print(f"Territory Manager state(s): {assigned_state[0]}")  # In New Jersey
# Out:
# Territory Manager: Miami Vue | Northeast
#
# Territory Manager state(s): New Jersey

# %%
# I would like to find what other territory manager exists in my region
print(f"Managers in the {assigned_region[0]} region: {store_details[store_details["Region"].isin(assigned_region)]["Territory Manager"].unique()}\n")
# Out:
# Managers in the Northeast region: ['Erbayne Middleton' 'Shruti Reddy' 'Bo Heap' 'Miami Vue']

# %%
# Finding second region to work with...
# print(f"{store_details[store_details["Territory Manager"] == "Erbayne Middleton"]["Region"].unique()}")  # Erbayne Middleton territories; Northeast only
# print(f"{store_details[store_details["Territory Manager"] == "Shruti Reddy"]["Region"].unique()}")  # Shruti Reddy territories; Northeast only
# print(f"{store_details[store_details["Territory Manager"] == "Bo Heap"]["Region"].unique()}")  # Bo Heap territories; Northeast only
# print(f"{store_details[store_details["Territory Manager"] == "Miami Vue"]["Region"].unique()}")  # Miami Vue territories; Northeast only

# assuming that each manager only has one region assigned to them... check for unique regions
print(f"List of regions and their corresponding managers:\n{store_details.groupby("Region")["Territory Manager"].unique()}\n")
print(f"Region directors:\n{store_details.groupby("Region")["Region Director"].unique()}\n")
# Out:
# List of regions and their corresponding managers:
# Region
# East                               [Ellen Lemon, See Ellefson]
# Northeast    [Erbayne Middleton, Shruti Reddy, Bo Heap, Mia...
# South          [Lana Ilana, Len Jensen, Jeff "Howdy" Richards]
# West                                                [Jim Heck]
# Name: Territory Manager, dtype: object
#
# Region directors:
# Region
# East               [Ana Jilani]
# Northeast      [Michael Jarvis]
# South        [Andy Gisselquist]
# West          [Cassie Chambers]
# Name: Region Director, dtype: object

# %%
# Since that means I'm assigned one region, let's find another region to work with. Since we want to drive revenue up, let's see how we rank against other regions
# first, check to see how each region ranks by combining tables and clean them

# join sales table and store details table together on store ID
sales_storedetails_merge = store_sales.merge(store_details, on="Store ID", how="left")
print(sales_storedetails_merge.head())

# cleaning our table
is_nan = sales_storedetails_merge[sales_storedetails_merge.isna().any(axis=1)]
# print(is_nan)

# RewardsID has lots of NaN values
# is_nan[is_nan.drop(columns=["RewardsID"]).isna().any(axis=1)]  # No NaN values exist outside of RewardsID
# Out:
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount Store Location  \
# 0         1/1/2022       702        NaN  105349-M         8.00       Berthoud
# 1         1/1/2022       704        NaN  105350-T       144.00    Castle Rock
# 2         1/1/2022       705        NaN  105351-M        44.00         Denver
# 3         1/1/2022       705        NaN  105352-M        47.61         Denver
# 4         1/1/2022       705        NaN  105353-A        20.36         Denver
#
#       State Territory Manager Region  Region Director
# 0  Colorado          Jim Heck   West  Cassie Chambers
# 1  Colorado          Jim Heck   West  Cassie Chambers
# 2  Colorado          Jim Heck   West  Cassie Chambers
# 3  Colorado          Jim Heck   West  Cassie Chambers
# 4  Colorado          Jim Heck   West  Cassie Chambers

# %%
# shorten the table view down to what we want
sales_storedetails_merge[["Store ID", "Sale Amount", "Store Location", "Territory Manager", "Region", "Region Director"]].groupby("Region")["Sale Amount"].sum().sort_values(ascending=False)

# Northeast > South > East > West; we'll compare against South since we're northeast.
assigned_region = np.append(assigned_region, "South")
print(assigned_region)
# Out:
# ['Northeast' 'South']

# %%
# Let's finally answer the question.
# Territory managers for the sales region assigned:

# Northeast: Erbayne Middleton, Shruti Reddy, Bo Heap, Miami Vue (4)
print(f"{assigned_region[0]} territory managers: {store_details[store_details["Region"] == assigned_region[0]]["Territory Manager"].unique()}\n")

# South: Lana Ilana, Len Jensen, Jeff "Howdy" Richards (3)
print(f"{assigned_region[1]} territory managers: {store_details[store_details["Region"] == assigned_region[1]]["Territory Manager"].unique()}\n")

# # # Any other territory manager in New Jersey? Just Miami Vue
# print(f"{assigned_state[0]} territory managers: {store_details[store_details["State"] == assigned_state[0]]["Territory Manager"].unique()}\n")
# Out:
# Northeast territory managers: ['Erbayne Middleton' 'Shruti Reddy' 'Bo Heap' 'Miami Vue']
#
# South territory managers: ['Lana Ilana' 'Len Jensen' 'Jeff "Howdy" Richards']

# %%
# Store IDs of each region
# print(store_details.head())
# print(store_details.groupby(["Region", "State", "Store Location", "Territory Manager"]).count())
# print(store_details.sort_values(by=["Territory Manager", "Region", "State", "Store Location".isin(assigned_region), "Store ID"]))

# Assigned region dataframe for store_details
assigned_store_details = (
    store_details[
        store_details["Region"].isin(assigned_region)
    ]
    .groupby(
        ["Territory Manager", "Region", "State", "Store Location"]
    )
    .size()
    .reset_index(name="Count")
)

# print(assigned_store_details)

# Northeast region (49)
print(f"{assigned_region[0]} store IDs: {store_details[store_details["Region"] == assigned_region[0]]["Store ID"].unique()}")
print(f"{assigned_region[0]} store count: {store_details[store_details["Region"] == assigned_region[0]]["Store ID"].count()}\n")

# Northeast region (24)
print(f"{assigned_region[1]} store IDs: {store_details[store_details["Region"] == assigned_region[1]]["Store ID"].unique()}")
print(f"{assigned_region[1]} store count: {store_details[store_details["Region"] == assigned_region[1]]["Store ID"].count()}")
# Out:
# Northeast store IDs: [818 819 820 821 822 823 731 732 733 734 735 736 737 738 739 730 801 802
#  803 804 805 806 807 808 809 810 811 812 813 814 815 816 817 824 825 826
#  827 828 829 830 831 832 833 834 835 836 837 838 839]
# Northeast store count: 49
#
# South store IDs: [719 720 721 722 723 724 725 726 727 728 729 852 853 901 902 903 904 905
#  906 907 908 909 910 911]
# South store count: 24

# %%
# Cities; there is one store for each city, number matches up to number of Count ID
# Northeast region (49)
print(f"{assigned_region[0]} store locations: {store_details[store_details["Region"] == assigned_region[0]]["Store Location"].unique()}")
print(f"{assigned_region[0]} store count: {store_details[store_details["Region"] == assigned_region[0]]["Store Location"].count()}\n")

# Northeast region (24)
print(f"{assigned_region[1]} store locationss: {store_details[store_details["Region"] == assigned_region[1]]["Store Location"].unique()}")
print(f"{assigned_region[1]} store count: {store_details[store_details["Region"] == assigned_region[1]]["Store Location"].count()}")
# Out:
# Northeast store locations: ['Bangor' 'Bar Harbor' 'Kennebunkport' 'Lewiston' 'Orono' 'South Portland'
#  'Annapolis' 'Back River' 'Baltimore' 'Germantown' 'Howard'
#  'North Harford' 'Parkville' "Queen Anne's County" 'Ridgely' 'Boston'
#  'Attleboro' 'Falmouth' 'Framingham' 'Haverhill' 'Hingham' 'Holyoke'
#  'Leominster' 'Lowell' 'Lynn' 'Nantucket' 'New Bedford' 'Northampton'
#  'Pittsfield' 'Provincetown' 'Quincy' 'Somerville' 'Worcester'
#  'Atlantic City' 'Bayonne' 'Cape May' 'Clifton' 'East Orange' 'Hackensack'
#  'Hoboken' 'Jersey City' 'Montclair' 'Morristown' 'New Brunswick' 'Newark'
#  'Passaic' 'Paterson' 'Trenton' 'Vineland']
# Northeast store count: 49
#
# South store locationss: ['Cape Canaveral' 'Fort Lauderdale' 'Jacksonville' 'Key West' 'Lakeland'
#  'Miami' 'Naples' 'Orlando' 'Sebring' 'Tallahassee' 'Tampa' 'Charleston'
#  'Greenville' 'Arlington' 'Austin' 'Bacliff' 'Baytown' 'Beaumont'
#  'Cedar Park' 'Dallas' 'Denton' 'Desoto' 'Fort Worth' 'Georgetown']
# ...

# %% [markdown]
# **What is monthly total revenue for in-store sales in each of the two sales territories, over the full period covered by the data?**

# %%
# Monthly 
# # Northeast region (49)
# print(f"{assigned_region[0]} store IDs: {store_details[store_details["Region"] == assigned_region[0]]["Store Location"].unique()}")
# print(f"{assigned_region[0]} store count: {store_details[store_details["Region"] == assigned_region[0]]["Store Location"].count()}\n")

# # Northeast region (24)
# print(f"{assigned_region[1]} store IDs: {store_details[store_details["Region"] == assigned_region[1]]["Store Location"].unique()}")
# print(f"{assigned_region[1]} store count: {store_details[store_details["Region"] == assigned_region[1]]["Store Location"].count()}")

# monthly_sales = sales_storedetails_merge.groupby(sales_storedetails_merge["Transaction Date"]

# searched additional functions using AI, aggregate by month and year
sales_storedetails_merge["Transaction Date"] = pd.to_datetime(sales_storedetails_merge["Transaction Date"])
sales_storedetails_merge["Year_Month"] = sales_storedetails_merge["Transaction Date"].dt.to_period("M")

regional_sales = (
    sales_storedetails_merge[
        sales_storedetails_merge["Region"].isin(assigned_region)
        # sales_storedetails_merge["Region"]
    ]
    .groupby(["Region", "Year_Month"])["Sale Amount"]  # trying to aggregate by date, group by region then store location
    .sum()
    .reset_index(name="Revenue")
)

print(regional_sales)

# Regional Revenue Over Time
# regional_sales["Year_Month"] = regional_sales["Year_Month"].astype(str)

# plt.figure(figsize=(12,6))

# # loop through each region
# for region in regional_sales["Region"].unique():
#     data = regional_sales[regional_sales["Region"] == region]
    
#     plt.plot(
#         data["Year_Month"],
#         data["Revenue"],
#         marker="o",
#         label=region
#     )

# plt.title("Monthly Revenue by Region")
# plt.xlabel("Year-Month")
# plt.ylabel("Revenue")
# plt.xticks(rotation=45)
# plt.legend()
# plt.tight_layout()
# plt.show()

# regional_sales.to_csv("regional_sales.csv", index=False)
# Out:
#        Region Year_Month    Revenue
# 0   Northeast    2022-01  345759.14
# 1   Northeast    2022-02  347379.16
# 2   Northeast    2022-03  375571.42
# 3   Northeast    2022-04  358972.37
# 4   Northeast    2022-05  383616.47
# ..        ...        ...        ...
# 91      South    2025-08  262942.14
# 92      South    2025-09  232498.44
# 93      South    2025-10  384663.47
# 94      South    2025-11  256920.74
# 95      South    2025-12  240485.82
#
# [96 rows x 3 columns]

# %% [markdown]
# **How would you rank the sales performance of each store in each sales territory? Which are the top-performing stores?**

# %%
# rank by revenue
store_revenue = (
    sales_storedetails_merge
    .groupby(["Region", "Store Location"])["Sale Amount"]  # by region then store location, can also substitute in for individual values
    .sum()
    .reset_index()
)

store_revenue["Sales_Rank"] = (
    store_revenue
    .groupby("Region")["Sale Amount"]
    .rank(method="dense", ascending=False)
)

store_revenue = store_revenue.sort_values(
    ["Region", "Sales_Rank", "Sale Amount"],
    ascending=[True, True, False]
)

# print(store_revenue)  # prints the ranking of all stores of their respective region

# top 5 stores per region
store_revenue_top5 = store_revenue[store_revenue["Sales_Rank"] <= 5]

print(store_revenue_top5)
# Out:
#         Region Store Location  Sale Amount  Sales_Rank
# 11        East       New York    621565.02         1.0
# 17        East      Rochester    607148.21         2.0
# 15        East    Poestenkill    334175.88         3.0
# 10        East     New London    331116.76         4.0
# 1         East     Bridgeport    322100.07         5.0
# 53   Northeast  North Harford   8708119.00         1.0
# 52   Northeast         Newark    623163.53         2.0
# 68   Northeast      Worcester    602183.44         3.0
# 66   Northeast        Trenton    597565.68         4.0
# 34   Northeast     Germantown    584675.92         5.0
# 73       South       Beaumont    637818.90         1.0
# 87       South          Miami    618846.25         2.0
# 91       South    Tallahassee    541670.66         3.0
# 81       South     Fort Worth    351772.59         4.0
# 83       South     Greenville    337002.00         5.0
# 97        West         Denver    917471.53         1.0
# ...

# %% [markdown]
# <span style="color:red">
#     What could possibly be happening in North Harford?
# </span>

# %% [markdown]
# **Comparing the customer ID from the customer list data with the rewards ID from the sales data, who were the top customers in each sales territory?**

# %%
# left join sales with customer list and remove NaNs or missing IDs
# need to include region, so merge with store details too
# print(sales_storedetails_merge)

sales_storedetails_customer_merge = sales_storedetails_merge.merge(customer_list, left_on="RewardsID", right_on="cust_id", how="left")  # keep transaction list, remove any member who hasn't made a transaction
sales_storedetails_customer_merge = sales_storedetails_customer_merge.dropna(subset=["RewardsID"])  # drop nan
sales_storedetails_customer_merge["RewardsID"] = sales_storedetails_customer_merge["RewardsID"].astype(int)  # convert from float to integer

# print(sales_storedetails_customer_merge)

# Previously raised an error, checking if it exists:
# Error existed due to overwriting dataframe
# print("RewardsID" in store_sales.columns)
# print("cust_id" in customer_list.columns)  # cust_id, not cust_ID
# print(customer_list.columns)
# print(store_sales)

# print(sales_customer_merge.head())

# cleaning 3-merged-table table
# customer_revenue = customer_revenue.drop(columns=["Transaction Date", "Store ID", "Prod Num", "Year_Month", "cust_id", "date", "time", "email", "phone", "sms-opt-out "])
customer_revenue = sales_storedetails_customer_merge[["Region", "State", "Store Location", "RewardsID", "name", "Sale Amount"]]

# print(customer_revenue)

# borrowed from earlier for revenue
# rank by individual revenue
customer_revenue = (
    customer_revenue
    .groupby(["Region", "RewardsID", "name"])["Sale Amount"]  # by region then store location, can also substitute in for individual values
    .sum()
    .reset_index()
)

percent_regional_revenue = (
    customer_revenue
    .groupby("Region")["Sale Amount"]
    .sum()
    .reset_index()
    .rename(columns={"Sale Amount": "Region_Revenue"})
)



customer_revenue = customer_revenue.merge(  # AI assisted
    percent_regional_revenue,
    on="Region",
    how="left"
)

customer_revenue["Pct_Region_Revenue"] = (  # AI assisted
    customer_revenue["Sale Amount"] / customer_revenue["Region_Revenue"] * 100
)

customer_revenue["Pct_Region_Revenue"] = (
    customer_revenue["Pct_Region_Revenue"]
    .round(2)
)



customer_revenue["Sales_Rank"] = (
    customer_revenue
    .groupby("Region")["Sale Amount"]
    .rank(method="dense", ascending=False)
)

customer_revenue = customer_revenue.sort_values(
    ["Region", "Sales_Rank", "RewardsID", "name", "Sale Amount"],
    ascending=[True, True, True, False, False]
)

# print(store_revenue)  # prints the ranking of all stores of their respective region

# top 5 stores per region
customer_revenue_top5 = customer_revenue[customer_revenue["Sales_Rank"] <= 5]

print(customer_revenue_top5[["Region", "RewardsID", "name", "Sale Amount", "Pct_Region_Revenue", "Sales_Rank"]])
# Out:
#          Region  RewardsID             name  Sale Amount  Pct_Region_Revenue  \
# 299        East        300    Julian Bashir      6281.57                0.89
# 321        East        322       Fox Mulder      5488.26                0.78
# 339        East        340         Jin Kwon      5410.55                0.77
# 20         East         21         Jon Snow      5009.79                0.71
# 116        East        117      Mr. McFeely      4891.02                0.70
# 700   Northeast        180       Cole Brown     12323.34                0.48
# 812   Northeast        292  Beverly Crusher     10109.86                0.39
# 916   Northeast        396          Stan Z.     10096.84                0.39
# 619   Northeast         99       Trent Lane     10059.04                0.39
# 770   Northeast        250          Michael      9612.09                0.37
# 1231      South        190             Huck      6460.68                0.76
# ...

# %% [markdown]
# <span style="color:red">
#     A couple of useful insights: top spenders reach close to 1% of total revenue sales. Each top spender buys enough for 5-7 people. There are a lot of frequent buyers, at least 60% in most regions.
# </span>

# %% [markdown]
# **What is the number of transactions per month by product category in each assigned territory? What is total sales revenue per month by category? What might this tell you about the most popular products, and where could there be opportunity for growth?**

# %%
# transaction count, aggregate similarly to region revenue
# join product details (category) to sales table
# print(store_sales.head(1))
# print(products.head(1))
# print(sales_storedetails_merge)

sales_products_merge = (
    sales_storedetails_merge
    .merge(products, on="Prod Num", how="left")
    .merge(product_categories, on="CategoryID", how="left")
)

# print(sales_products_merge)

# borrowed from monthly sales
# sales_products_merge["Transaction Date"] = pd.to_datetime(sales_products_merge["Transaction Date"])
# sales_products_merge["Year_Month"] = sales_products_merge["Transaction Date"].dt.to_period("M")

regional_inventory_summary = (
    sales_products_merge[
        sales_products_merge["Region"].isin(assigned_region)
    ]
    .groupby(["Region", "Year_Month", "Category",])  # by region then store location, can also substitute in for individual values
    .aggregate(  # multiple aggregation, doing both sum and count
        Revenue = ("Sale Amount", "sum"),
        Transaction_Count = ("Sale Amount", "size")
    )
    .reset_index()
)

# regional_inventory_summary["Revenue_Rank"] = (
#     regional_inventory_summary
#     .groupby("Region")["Revenue"]
#     .rank(method="dense", ascending=False)
# )

# regional_inventory_summary["Volume_Rank"] = (
#     regional_inventory_summary
#     .groupby("Region")["Transaction_Count"]
#     .rank(method="dense", ascending=False)
# )

# regional_inventory_summary = regional_inventory_summary.drop(columns=["Transaction Date", "Store ID", "RewardsID", "Region Director", "CategoryID", "SubcategoryID_x"])

# Northeast region
print(f"\n{assigned_region[0]}: ")
NE_monthly_revenue = (
    regional_inventory_summary[
        regional_inventory_summary["Region"] == assigned_region[0]
    ]
    .sort_values(["Region", "Year_Month", "Revenue"], ascending=[True, True, False])
    .groupby(["Region", "Year_Month", "Category"])
    .aggregate({"Revenue": "sum"})
    .reset_index()
)
print(NE_monthly_revenue[["Region", "Year_Month", "Category", "Revenue"]])

NE_monthly_volume = (
    regional_inventory_summary[
        regional_inventory_summary["Region"] == assigned_region[0]
    ]
    .sort_values(["Region", "Year_Month", "Transaction_Count"], ascending=[True, True, False])
    .groupby(["Region", "Year_Month", "Category"])
    .aggregate({"Transaction_Count": "sum"})
    .reset_index()
)

print(NE_monthly_volume[["Region", "Year_Month", "Category", "Transaction_Count"]])

# South region
print(f"\n{assigned_region[1]}: ")
S_monthly_revenue = (
    regional_inventory_summary[
        regional_inventory_summary["Region"] == assigned_region[1]
    ]
    .sort_values(["Region", "Year_Month", "Revenue"], ascending=[True, True, False])
    .groupby(["Region", "Year_Month", "Category"])
    .aggregate({"Revenue": "sum"})
    .reset_index()
)
print(S_monthly_revenue[["Region", "Year_Month", "Category", "Revenue"]])

S_monthly_volume = (
    regional_inventory_summary[
        regional_inventory_summary["Region"] == assigned_region[1]
    ]
    .sort_values(["Region", "Year_Month", "Transaction_Count"], ascending=[True, True, False])
    .groupby(["Region", "Year_Month", "Category"])
    .aggregate({"Transaction_Count": "sum"})
    .reset_index()
)

print(S_monthly_volume[["Region", "Year_Month", "Category", "Transaction_Count"]])
# Out:
# Northeast:
#         Region Year_Month                  Category     Revenue
# 0    Northeast    2022-01   Apparel and Merchandise   120183.12
# 1    Northeast    2022-01              Art Supplies   156387.11
# 2    Northeast    2022-01           Books (General)    53733.72
# 3    Northeast    2022-01   Stationery and Supplies    55115.61
# 4    Northeast    2022-01  Technology & Accessories  1567309.24
# ..         ...        ...                       ...         ...
# 283  Northeast    2025-12              Art Supplies   291447.75
# 284  Northeast    2025-12           Books (General)    70848.12
# 285  Northeast    2025-12   Stationery and Supplies   115265.59
# 286  Northeast    2025-12  Technology & Accessories  4042468.15
# 287  Northeast    2025-12                 Textbooks  1005323.22
#
# [288 rows x 4 columns]
#         Region Year_Month                  Category  Transaction_Count
# 0    Northeast    2022-01   Apparel and Merchandise               3616
# ...

# %%
# graph preparation; the following graph dimensions were assisted by AI
regional_inventory_summary["Year_Month"] = regional_inventory_summary["Year_Month"].astype(str)

# revenue line chart
# aggregate revenue at Region + Month level
region_monthly_revenue = (
    regional_inventory_summary
    .groupby(["Region", "Year_Month"])["Revenue"]
    .sum()
    .reset_index()
)

plt.figure(figsize=(12,6))

for region in region_monthly_revenue["Region"].unique():
    data = region_monthly_revenue[region_monthly_revenue["Region"] == region]
    
    plt.plot(
        data["Year_Month"],
        data["Revenue"],
        marker="o",
        label=region
    )

plt.title("Monthly Revenue by Region")
plt.xlabel("Year-Month")
plt.ylabel("Revenue ($)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(14,7))

# northeast
region_data = regional_inventory_summary[
    regional_inventory_summary["Region"] == assigned_region[0]
]

for category in region_data["Category"].unique():
    cat_data = region_data[region_data["Category"] == category]
    
    monthly = cat_data.groupby("Year_Month")["Revenue"].sum().reset_index()
    
    plt.plot(
        monthly["Year_Month"],
        monthly["Revenue"],
        marker="o",
        label=category
    )

plt.title(f"Monthly Transaction Count by Category - {assigned_region[0]}")
plt.xlabel("Year-Month")
plt.ylabel("Revenue ($)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="color:red">
#     Our big ticket items are in technology & accessories, followed by books. Other categories generate similar revenue value. Technology generates an upward trend while textbooks generally remained stagnant. We love laptops and PC-related items.
# </span>

# %%
# transaction count line chart
# aggregate at Region + Month level
region_monthly_txn = (
    regional_inventory_summary
    .groupby(["Region", "Year_Month"])["Transaction_Count"]
    .sum()
    .reset_index()
)

plt.figure(figsize=(12,6))

for region in region_monthly_txn["Region"].unique():
    data = region_monthly_txn[region_monthly_txn["Region"] == region]
    plt.plot(
        data["Year_Month"],
        data["Transaction_Count"],
        marker="o",
        label=region
    )

plt.title("Monthly Transaction Count by Region")
plt.xlabel("Year-Month")
plt.ylabel("Transaction Count (Units)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(14,7))

# northeast
region_data = regional_inventory_summary[
    regional_inventory_summary["Region"] == assigned_region[0]
]

for category in region_data["Category"].unique():
    cat_data = region_data[region_data["Category"] == category]
    
    monthly = cat_data.groupby("Year_Month")["Transaction_Count"].sum().reset_index()
    
    plt.plot(
        monthly["Year_Month"],
        monthly["Transaction_Count"],
        marker="o",
        label=category
    )

plt.title(f"Monthly Transaction Count by Category - {assigned_region[0]}")
plt.xlabel("Year-Month")
plt.ylabel("Transaction Count (Units)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <span style="color:red">
# There is a steady increase of purchases throughout the years, which illustrates that demand continues to grow for products offered by EmporiUm.
#
# The spikes in transaction counts suggests a back-to-school sale, where post-COVID in-person learning resumes and students are back in class, 2025. The decrease in textbooks but increase in books (general) also suggests that students are either getting second-hand copies externally for cheaper, or even a switch to e-books and access codes from notable players like Pearson, McGraw Hill, or Cengage.
# </span>

# %% [markdown]
# **What is your recommendation for where to focus marketing attention in the next quarter?**

# %% [markdown]
# ### Making Predictions:
# - As population and store availability increases, revenue will also increase (#1)
#     - More people means more purchases
#     - It does not necessarily mean more profit, only increase in revenue (example of correlation != causation)
#         - A couple of technology purchases overshadows multiple book purchases
#         - All regions have 521 members
#     - Stores are simply more productive in the Northeast coast than any other region
# - Since our largest source of revenue comes from selling technology and textbooks ($$$)
#     - Offer the latest tech and push it towards the front of the store to catch students
#     - Push access codes and subscriptions rather than hardcovers (or bundle with hardcovers) and generate infinite money
#     - (Unethical) Work with professors to make it mandatory
# - Offer tech services and book buybacks to save costs on purchasing books and make free money (donation events)
#
#
#
# ### To investigate:
# - Check where customers have been a member with us but have not made any purchases
#     - Since we are currently on a positive trend with progress, we should be judged by our 'losses' and try to win back customer loyalty
# - Make a case study on Miami Vue's best performing store compared to the chain's best performing store across all region
#     - Confirm that population drives revenue rather than product diversity
# - How to increase customer loyalty and sales outside of occasional semester sales
#     - Expand to other services while retaining bookstore quality
#     - Instead of trying to bring customers in to buy things, why not make it easier for them to buy by bringing stuff to them
#         - Similar to Amazon, expand outside of local market and less brick & mortar shops to save costs

# %% [markdown]
# ## Additional supporting analysis

# %%
# 1
# yearly customer count across all region; AI-assisted
sales_storedetails_customer_merge["Year"] = (
    sales_storedetails_customer_merge["Transaction Date"].dt.year
)

customer_count_yearly = (
    sales_storedetails_customer_merge
    .groupby(["Year", "Region"])["RewardsID"]
    .nunique()
    .reset_index()
    .rename(columns={"RewardsID": "Customer_Count"})
)

customer_count_yearly = customer_count_yearly.sort_values(
    by=["Year", "Region", "Customer_Count"],
    ascending=[True, True, False]
)

print(customer_count_yearly)
# Northeast unique customers always around max amount specified, 521
# increase comes from # of customers, # of available stores, and a missing external factor
# instead of per student count, it could possibly be wholesale from a third-party provider since Northeast covers a larger region
# or they may simply be spending more than other average customers, higher transaction count too
# stores are more productive
# Out:
#     Year     Region  Customer_Count
# 0   2022       East             390
# 1   2022  Northeast             519
# 2   2022      South             431
# 3   2022       West             378
# 4   2023       East             461
# 5   2023  Northeast             520
# 6   2023      South             478
# 7   2023       West             459
# 8   2024       East             458
# 9   2024  Northeast             520
# 10  2024      South             485
# 11  2024       West             452
# 12  2025       East             514
# 13  2025  Northeast             521
# 14  2025      South             517
# 15  2025       West             508

# %% [markdown]
# **Acknowledgements**
# - Nigel (query assistance, Capstone clarification)
# - Onur, Rodas, Maritza, Julissa, Jimmy (peer assistance)
# - Kidus (jupyter notebook format)
# - Angel (for making this harder than it already is)
# - Dr. G, PT.
#     - OpenAI. (2025). ChatGPT (GPT-5.5) [Large language model]. https://chatgpt.com
#
# **Challenges and Limitations**
# - Balancing between health and sickness
# - Setting up matplotlib and queries, limited time and resources so chose to be resourceful with workbook and AI-assistance
#     - Effective prompt engineering
#
# **Future Improvements and Recommendations**
# - Follow through with the case study and determine whether the quality, quantity, or marketing and promotions of products should be prioritized more
# - Final analysis after these summary will be best store of our manager vs best store overall, it will be a case study
# - Discover any competitors, especially tackling on the ecommerce market
# - Find out what is happening in North Harford that they are generating ludicrous revenue (population ~145000)
